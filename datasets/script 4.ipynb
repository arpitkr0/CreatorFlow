# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df.insert(loc=0, column='niche', value="history")

# %%
df.head()
# Out:
#      niche     video_id                                   video_link  \
# 0  history  yjmp8CoZBIo  https://www.youtube.com/watch?v=yjmp8CoZBIo
# 1  history  9wSOt3z_-YY  https://www.youtube.com/watch?v=9wSOt3z_-YY
# 2  history  zRqz193a8gk  https://www.youtube.com/watch?v=zRqz193a8gk
# 3  history  cvCv7kTcRXI  https://www.youtube.com/watch?v=cvCv7kTcRXI
# 4  history  H_NryL40-lw  https://www.youtube.com/watch?v=H_NryL40-lw
#
#                                                title  \
# 0           One Direction - History (Official Video)
# 1           History's "worst" nun - Theresa A. Yugar
# 2  Invention of Slinky Toy | History of the Slink...
# 3  Story of Ramayana | Why is Diwali called the F...
# 4    Titanic | The Story Lives On | Stories for Kids
#
#                          channel_title          published_at  view_count  \
# 0                     OneDirectionVEVO  2016-01-26T16:00:04Z   457399052
# 1                               TED-Ed  2019-11-21T16:00:28Z     9806611
# 2                        Peekaboo Kidz  2023-09-01T12:30:36Z     1505688
# 3                        Peekaboo Kidz  2024-11-01T12:30:30Z     1060765
# 4  Little Fox - Kids Stories and Songs  2022-04-04T13:00:07Z      884130
#
#    like_count  comment_count duration  duration_seconds  \
# 0     5547946         438433  PT3M16S             196.0
# 1      361913           7588  PT4M47S             287.0
# 2        3621              0  PT5M47S             347.0
# 3        4655              0  PT5M19S             319.0
# 4        1455              0  PT4M51S             291.0
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/yjmp8CoZBIo/hqdefault.jpg
# 1  https://i.ytimg.com/vi/9wSOt3z_-YY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/zRqz193a8gk/hqdefault.jpg
# 3  https://i.ytimg.com/vi/cvCv7kTcRXI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/H_NryL40-lw/hqdefault.jpg
#
#                                           transcript region
# 0  (upbeat music) ♪ You gotta help me, I'm losin'...     US
# 1  Juana Ramírez de Asbaje sat before a panel\nof...     US
# 2  foreign kitty it's time for a little lunch [Mu...     US
# 3  Diwali is one of India's biggest and most impo...     US
# 4  [Music] little box [Music] titanic the story l...     US

# %%
df.to_csv('history-dataset.csv', index=False)

# %%
import os
file_path = 'history_dataset.csv'

if os.path.exists(file_path):
    file_link = FileLink(file_path)
    print(f"Click the link below to download '{file_path}':")
    display(file_link)
