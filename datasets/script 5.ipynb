# %%
import pandas as pd 
df = pd.read_csv('shuffled_dataset_with_main_idea.csv')

# %%
df_cleaned = df.drop(columns=['video_id','view_count','like_count','comment_count'])

# %%
df_cleaned.head()
# Out:
#           niche                                   video_link  \
# 0  fighter jets  https://www.youtube.com/watch?v=yeD25bjiA-E
# 1     tech news  https://www.youtube.com/watch?v=x2WtHZciC74
# 2           NaN  https://www.youtube.com/watch?v=EmJpb9eLplI
# 3           MMA  https://www.youtube.com/watch?v=THrr1VDYDdo
# 4  fighter jets  https://www.youtube.com/watch?v=MjtQC4o6Ux8
#
#                                                title    channel_title  \
# 0  Russian Air Force Receives First Su-35S 4++ Fi...    Military Gear
# 1              Claude 3.7 goes hard for programmers…         Fireship
# 2  4 TYPES OF BODYFAT YOU MUST KNOW (The Fat Scie...  ABHINAV MAHAJAN
# 3  Rodtang Jitmuangnon (Thailand) vs Edgar Tabare...  That's why MMA!
# 4  How Iran Built the Saegheh Fighter Jet Under H...         SHKamran
#
#            published_at duration  duration_seconds  \
# 0  2025-04-16T12:01:49Z  PT8M11S             491.0
# 1  2025-02-25T18:27:50Z  PT5M49S             349.0
# ...

# %%
final_df = df_cleaned.dropna()

# %%
len(final_df)
# Out:
# 220

# %%
final_df.to_csv('final_dataset.csv', index=False)

# %%
final_df.head()
# Out:
#           niche                                   video_link  \
# 0  fighter jets  https://www.youtube.com/watch?v=yeD25bjiA-E
# 1     tech news  https://www.youtube.com/watch?v=x2WtHZciC74
# 3           MMA  https://www.youtube.com/watch?v=THrr1VDYDdo
# 4  fighter jets  https://www.youtube.com/watch?v=MjtQC4o6Ux8
# 7           MMA  https://www.youtube.com/watch?v=COE9FzEpdKA
#
#                                                title            channel_title  \
# 0  Russian Air Force Receives First Su-35S 4++ Fi...            Military Gear
# 1              Claude 3.7 goes hard for programmers…                 Fireship
# 3  Rodtang Jitmuangnon (Thailand) vs Edgar Tabare...          That's why MMA!
# 4  How Iran Built the Saegheh Fighter Jet Under H...                 SHKamran
# 7  When Muay Thai Legend Challenges a Master of M...  Fight Legends Unleashed
#
#            published_at duration  duration_seconds  \
# 0  2025-04-16T12:01:49Z  PT8M11S             491.0
# ...

# %%
final_df = final_df.drop(columns=['duration','main_idea'])

# %%
final_df.head()
# Out:
#           niche                                   video_link  \
# 0  fighter jets  https://www.youtube.com/watch?v=yeD25bjiA-E
# 1     tech news  https://www.youtube.com/watch?v=x2WtHZciC74
# 3           MMA  https://www.youtube.com/watch?v=THrr1VDYDdo
# 4  fighter jets  https://www.youtube.com/watch?v=MjtQC4o6Ux8
# 7           MMA  https://www.youtube.com/watch?v=COE9FzEpdKA
#
#                                                title            channel_title  \
# 0  Russian Air Force Receives First Su-35S 4++ Fi...            Military Gear
# 1              Claude 3.7 goes hard for programmers…                 Fireship
# 3  Rodtang Jitmuangnon (Thailand) vs Edgar Tabare...          That's why MMA!
# 4  How Iran Built the Saegheh Fighter Jet Under H...                 SHKamran
# 7  When Muay Thai Legend Challenges a Master of M...  Fight Legends Unleashed
#
#            published_at  duration_seconds  \
# 0  2025-04-16T12:01:49Z             491.0
# ...

# %%
final_df.to_csv('new.csv')

# %%
lat_df = pd.read_csv('newest.csv')

# %%
lat_df.tail()
# Out:
#      Unnamed: 0      niche                                   video_link  \
# 215         342  tech news  https://www.youtube.com/watch?v=lWY2q90lbWg
# 216         343     coding  https://www.youtube.com/watch?v=oMDaaYagg_Y
# 217         345    Economy  https://www.youtube.com/watch?v=3G-vTV9SVW4
# 218         346    Economy  https://www.youtube.com/watch?v=1l-jN8V_puk
# 219         348    Economy  https://www.youtube.com/watch?v=5lXSpKsB09E
#
#                                                  title     channel_title  \
# 215  How AI is changing gaming tech in 2025 | BBC News          BBC News
# 216   I voiced over Alan Becker's Animation vs. Coding            Dippid
# 217     What A U.S. Economy Under Trump Will Look Like              CNBC
# 218  Mass government layoffs: Impact on the labor f...   CNBC Television
# 219  Why the Economy is Broken & Rich People Run Of...  High Performance
#
#              published_at  duration_seconds  \
# 215  2025-04-12T11:01:12Z             351.0
# ...

# %%
lat_df['niche'][219],lat_df['title'][219],lat_df['Main Idea'][219]
# Out:
# ('Economy',
#  'Why the Economy is Broken & Rich People Run Off to Dubai | Gary Stevenson',
#  'Make a video on Elon Musk’s unexpected impact on the housing market, analyzing what he said or did and why it caught the industry by surprise.')

# %%
len(lat_df)
# Out:
# 220

# %%
main_df = pd.read_csv('main_ideas.csv')

# %%
len(main_df)
# Out:
# 220
